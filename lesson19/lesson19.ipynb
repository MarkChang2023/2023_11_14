# %%
#建立並整理隨機亂數的2維資料
import numpy as np
import pandas as pd
scores = np.random.randint(50, 101, size=(50,5))
scores_pd = pd.DataFrame(scores,
                         columns=['國文', '英文', '數學', '地理', '歷史'],
                         index=range(1,51)
                         )
scores_pd
# Out:
#      國文   英文   數學  地理  歷史
# 1    96   87   78  85  97
# 2    95   54   55  93  75
# 3    80   61   84  99  99
# 4    76   79   89  58  75
# 5    67   86   63  52  65
# 6    53   58   73  69  96
# 7    82   55   71  78  97
# 8    61   55   93  57  76
# 9    77   90   93  63  62
# 10   71   77   69  66  71
# 11   91   80   90  54  68
# 12   66   57   91  91  77
# 13   94   85   60  74  60
# 14   62   73   55  85  61
# 15   61   57   54  63  81
# 16   83   50   52  73  92
# 17   54   93   84  82  73
# 18   70   90   72  87  70
# 19   85   76   95  63  90
# 20   82   65  100  54  90
# 21   64   96   56  69  61
# 22   74   67   99  72  84
# 23   61   65   82  74  94
# 24   87   97   76  98  72
# 25   63   86   54  55  92
# 26   96   71   79  64  57
# 27   90   82   87  94  68
# 28   56   93   58  98  69
# 29   71   67   69  92  79
# 30   60   56   55  72  98
# 31   83   82   52  87  65
# 32   95   82   74  73  89
# 33  100   89   79  68  93
# 34   53   50   95  56  77
# ...
